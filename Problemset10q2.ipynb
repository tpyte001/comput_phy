# %% [markdown]
# <a href="https://colab.research.google.com/github/tpyte001/comput_phy/blob/main/Problemset10q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def dydx(x,y):
  return np.e**x

### y1 ###

x = 0   #initial conditions
y = 1   #
h = 0.1 # step size
N = 10# eulers method upper limit

xlist = []
ylist = []

while x < 3:
  xlist.append(x)
  y_next = y + h*(np.e ** (x))
  ylist.append(y)
  y = y_next
  x = x + h
'''
for i in range(N):
  y = (1/N) * (1 + N + np.e**(i/N))
  print(y)

'''
print(len(ylist), ";", ylist)
plt.plot(xlist,ylist)
# Out:
# 30 ; [1, 1.1, 1.210517091807565, 1.332657367623582, 1.4676432483811823, 1.6168257181453094, 1.7816978452153223, 1.9639097252543731, 2.1652849960014207, 2.3878390888506673, 2.633799399966362, 2.9056275828122664, 3.2060441852069097, 3.5380558774805646, 3.9049855442424892, 4.310505540926957, 4.758674447960763, 5.253977690400275, 5.801372429572995, 6.40633717601429, 7.074926620242217, 7.813832230135283, 8.630449221392048, 9.53295057133546, 10.530368816816933, 11.632686454881094, 12.850935850951442, 14.197309654451612, 15.685282826938897, 17.329747504048605]
